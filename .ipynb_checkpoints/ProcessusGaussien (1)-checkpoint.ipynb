# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import tensorflow.keras
import time

# %%
# Nombre de points totals
N = 1000
# Nombre de points d'entrainement 
n_train = 200
# Création de données synthétiques
x = np.linspace(1, 10, N) # peut changer en np.linspace(0, 10, N) pour les fonctions sans le log()

# %% [markdown]
# OBJECTIF : Comparer NN et PG sur la prédiction d'une fonction à l'aide de n_train points pour prédire N points ensuite

# %% [markdown]
# Fonction à prédire

# %%
#y = np.cos(x)
#y = np.cos(x) + x**2 -20 * np.sin(5 * x) 
y = np.log(x) + np.cos(x**2)*4*x

# %%
plt.plot(x, y, label='Données originales')

# %% [markdown]
# Testons avec differents kernels

# %%
from sklearn.gaussian_process.kernels import RationalQuadratic
from sklearn.gaussian_process.kernels import ExpSineSquared
from sklearn.gaussian_process.kernels import Matern
kernel_possible = ["RationalQuadratic", "ExpSineSquared", "Matern","RBF"] # "RBF" (celui par défaut)
indices = np.random.choice(range(N), size=n_train, replace=False)
x_chosen = x[indices]
y_chosen = y[indices]
for kernel_name  in kernel_possible:
     isRBF = False
     if(kernel_name == "RationalQuadratic"):
          kernel = RationalQuadratic(length_scale=1.0, alpha=1.0)
     elif(kernel_name == "ExpSineSquared"):
          kernel = ExpSineSquared(length_scale=1.0, periodicity=3.0) 
     elif(kernel_name == "Matern"):
          kernel = Matern(length_scale=1.0, nu=1.5)
     else:
         isRBF = True
     plt.figure(figsize=(8, 4))

     # Données originales et points choisis
     plt.plot(x, y, label='Données originales', linestyle='dashed')
     plt.scatter(x_chosen, y_chosen, color='red', label='Points choisis')
     # Modèle de processus gaussien
     
     start_time = time.time()
     if (isRBF == False): 
         gp = sklearn.gaussian_process.GaussianProcessRegressor(kernel=kernel)
     else:
         gp = sklearn.gaussian_process.GaussianProcessRegressor() # RBF par défaut
         
     gp.fit(x_chosen.reshape(-1, 1), y_chosen.reshape(-1, 1)) # entrainement avec n_train points
     end_time = time.time()
     print("Temps d'exécution pour le kernel", kernel_name, "avec", n_train, "points :", end_time - start_time, "secondes")
     print("Le nombre de paramètres est de", gp.kernel_.n_dims, "pour le kernel", kernel_name)

     y_pred = gp.predict(x.reshape(-1, 1))
     mse = mean_squared_error(y, y_pred)
     print("Mean Squared Error :", mse)
     # Prédiction
     plt.plot(x, y_pred, label='Prédiction GP')

     plt.legend()
     plt.title(f"Approximation avec {n_train} points et avec le kernel {kernel_name}")
     plt.show()
# Out:
# Temps d'exécution pour le kernel RationalQuadratic avec 200 points : 0.18802428245544434 secondes
# Le nombre de paramètres est de 2 pour le kernel RationalQuadratic
# Mean Squared Error : 5.49063682401328
# Temps d'exécution pour le kernel ExpSineSquared avec 200 points : 0.00810551643371582 secondes
# Le nombre de paramètres est de 2 pour le kernel ExpSineSquared
# Mean Squared Error : 215.36545338923082
# Temps d'exécution pour le kernel Matern avec 200 points : 0.0054988861083984375 secondes
# Le nombre de paramètres est de 1 pour le kernel Matern
# Mean Squared Error : 245.76474723885644
# c:\Users\loicd\anaconda3\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Temps d'exécution pour le kernel RBF avec 200 points : 0.001811981201171875 secondes
# Le nombre de paramètres est de 0 pour le kernel RBF
# Mean Squared Error : 906.1680876127859

# %% [markdown]
# Comparaison avec un NN

# %%
# normalisation

# # norme train
x_chosen_min, x_chosen_max = np.min(x_chosen), np.max(x_chosen)
x_chosen_norm = (x_chosen  - x_chosen_min) / (x_chosen_max - x_chosen_min) 

y_chosen_min, y_chosen_max = np.min(y_chosen), np.max(y_chosen)
y_chosen_norm = (y_chosen - y_chosen_min) / (y_chosen_max - y_chosen_min) 

# norme test

x_min, x_max = np.min(x), np.max(x)
x_norm = (x - x_min) / (x_max - x_min) 

y_min, y_max = np.min(y), np.max(y)
y_norm = (y - y_min) / (y_max - y_min)

# %%
# architecture du modèle
inputs = tf.keras.Input(shape=(1,))
x1 = tf.keras.layers.Dense(64, activation='relu')(inputs)
x2 = tf.keras.layers.Dense(64, activation='relu')(x1)
outputs = tf.keras.layers.Dense(1)(x2)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)
start_time = time.time()
model.compile(optimizer=optimizer, loss='mse')
model.fit(x_chosen_norm, y_chosen_norm, epochs=100, batch_size=32)
end_time = time.time()
print("Temps d'exécution du réseau de neurones avec", n_train, "points :", end_time - start_time, "secondes")
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1506
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0859
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0612
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0535
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0497
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0456
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0451
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0456
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0456
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0479
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0482
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0484
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0466
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0473
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0446
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0475
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0484
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0471
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0472
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0468
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0477
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0488
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0449
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0458
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0470
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0472
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0489
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0453
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0466
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0488
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0502
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0456
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0477
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0465
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0454
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452
# Temps d'exécution du réseau de neurones avec 200 points : 3.3834195137023926 secondes

# %%
y_pred_norm = model.predict(x_norm)
y_pred = y_pred_norm * (y_max - y_min) + y_min
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error :", mse)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error : 295.3102514740282

# %%
plt.plot(x, y, label='Données réelles')
plt.plot(x, y_pred, label=f'Prédictions du modèle avec {n_train} points d entrainement')
plt.legend()
plt.show()

# %%
# nombre de paramètres du réseau de neurones
total_params = model.count_params()
print("Le nombre de paramètres du réseau de neurones est de :", total_params)
# Out:
# Le nombre de paramètres du réseau de neurones est de : 4353
